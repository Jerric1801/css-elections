# %%
import pandas as pd
from collections import Counter
import requests
from bs4 import BeautifulSoup

directory = "../datasets/"
file = "second-debate"
elections_dataset = pd.read_csv(directory + file + ".csv", chunksize=2000)

# %%
#scrape fact checking webpage for context

fact_check_url = "https://www.factcheck.org/2016/07/clintons-handling-of-classified-information/"
response = requests.get(fact_check_url)
response.raise_for_status()  # Check for errors

soup = BeautifulSoup(response.text, "html.parser")

scrapped_data = {}

title = soup.find("h1").text
scrapped_data["title"] = title

# change this based on site you are scrapping
site_class = "entry-content"

div = soup.find("div", {"class": site_class})
info = div.find_all("p")

content = []

for p in info:
    content.append(p.text)

scrapped_data["content"] = content

print(scrapped_data)
# Out:
# {'title': 'Clinton’s Handling of Classified Information', 'content': ['An FBI investigation into former Secretary of State Hillary Clinton’s mishandling of classified information resulted in no criminal charges, but it revealed that Clinton and her campaign made statements in the past about her email use that have turned out to be false or misleading:', 'As we did in May, when the State Department’s inspector general issued a report on Clinton’s unusual email arrangement, we will take a look at past statements Clinton has made about her personal emails and private server and how they square with the results of the FBI investigation announced on July 5.', 'Clinton, the presumptive Democratic presidential nominee, has denied mishandling classified information ever since the\xa0New York Times\xa0on March 2, 2015, disclosed that Clinton “exclusively used a personal email account to conduct government business as secretary of state.”', 'At a March 10 press conference, Clinton addressed her unusual email arrangement. Her office at the time said that on Dec. 5, 2014, it gave the State Department 30,490 printed copies of work-related emails.\xa0Clinton said none of them contained classified information.', 'Clinton, March 10, 2015:\xa0I did not email any classified material to anyone on my email. There is no classified material.\xa0So I’m certainly well-aware of the classification requirements and did not send classified material.', 'On the same day, her office released a Q&A that said a “separate, closed email system was used by the State Department for the sole purpose of handling classified communications\xa0which was designed to prevent such information from being transmitted anywhere other than within that system.”', 'But about four months later, the inspectors general of the State Department and the Intelligence Community reviewed 40 of Clinton’s emails and\xa0found that four did contain classified information, referring the case to the FBI for what they called an investigation into the “potential compromise of classified information.” \xa0The inspectors general said the four emails “did not contain classification markings.”', 'After the inspectors general reported its findings, Clinton and her campaign amended their public statements to say that she did not send or receive information that was marked classified. But that has turned out to be false, too.', 'For example, the Clinton campaign last year released an “updated fact sheet” on Clinton’s emails that said, “No information in Clinton’s emails was marked classified at the time she sent or received them.” The campaign said “it is common for information previously unclassified to be upgraded to classified” when emails are reviewed for public release.', 'Clinton told Fox News’ Bret Baier at a March 7 town hall event, “Nothing I sent was marked classified or that I received was marked classified.” She later said in the same event, “I will reiterate, because it’s a fact, nothing I sent or received was marked classified.”', 'Below are other examples of statements Clinton made\xa0this year, including one just two days before the FBI director revealed the department’s findings:', 'Clinton at a Democratic debate, Feb. 4:\xa0I never sent or received any classified material.', 'Clinton at a Democratic debate, March 9:\xa0But here’s the cut to the chase facts. I did not send or receive any emails marked classified at the time.', 'Clinton on CBS’ “Face the Nation,” May 8:\xa0There was never any material marked classified that was sent or received by me.', 'Clinton on NBC’s “Meet the Press,” July 3: I never received nor sent any material that was marked classified.', 'We now know from the FBI investigation that:', 'At his July 5 press conference, Comey\xa0announced his office will not recommend that charges be brought against Clinton or her staff. But the FBI director said Clinton and her staff “were extremely careless in their handling of very sensitive, highly classified information.”', ...

# %%
#text normalization of scrapped data
import re  # For regular expressions
import nltk  # Natural Language Toolkit (if you need stop words or advanced features)

nltk.download('punkt') # Download for sentence tokenization (if needed)
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

content = scrapped_data["content"]


def normalize_text(text):
    # 1. Lowercasing
    text = text.lower()

    # 2. Punctuation Removal (adjust as needed)
    text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation except for basic word characters and spaces

    # 3. Tokenization (optional, for word-by-word analysis)
    tokens = nltk.word_tokenize(text) 

    # 4. Stop Word Removal (optional)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # 5. Recombine tokens into text (if you did tokenization):
    normalized_text = " ".join(tokens)

    return normalized_text

# Apply normalization to your content
normalized_content = []
for para in content:
    normalized_para = normalize_text(para)
    normalized_content.append(normalized_para)

print(normalized_content)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jerricchan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jerricchan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jerricchan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/jerricchan/nltk_data...
# ['fbi investigation former secretary state hillary clintons mishandling classified information resulted criminal charges revealed clinton campaign made statements past email use turned false misleading', 'may state departments inspector general issued report clintons unusual email arrangement take look past statements clinton made personal emails private server square results fbi investigation announced july 5', 'clinton presumptive democratic presidential nominee denied mishandling classified information ever since new york times march 2 2015 disclosed clinton exclusively used personal email account conduct government business secretary state', 'march 10 press conference clinton addressed unusual email arrangement office time said dec 5 2014 gave state department 30490 printed copies workrelated emails clinton said none contained classified information', 'clinton march 10 2015 email classified material anyone email classified material im certainly wellaware classification requirements send classified material', 'day office released qa said separate closed email system used state department sole purpose handling classified communications designed prevent information transmitted anywhere within system', 'four months later inspectors general state department intelligence community reviewed 40 clintons emails found four contain classified information referring case fbi called investigation potential compromise classified information inspectors general said four emails contain classification markings', 'inspectors general reported findings clinton campaign amended public statements say send receive information marked classified turned false', 'example clinton campaign last year released updated fact sheet clintons emails said information clintons emails marked classified time sent received campaign said common information previously unclassified upgraded classified emails reviewed public release', 'clinton told fox news bret baier march 7 town hall event nothing sent marked classified received marked classified later said event reiterate fact nothing sent received marked classified', 'examples statements clinton made year including one two days fbi director revealed departments findings', 'clinton democratic debate feb 4 never sent received classified material', 'clinton democratic debate march 9 heres cut chase facts send receive emails marked classified time', 'clinton cbs face nation may 8 never material marked classified sent received', 'clinton nbcs meet press july 3 never received sent material marked classified', 'know fbi investigation', 'july 5 press conference comey announced office recommend charges brought clinton staff fbi director said clinton staff extremely careless handling sensitive highly classified information', 'small number emails containing classified information bore markings indicating presence classified information comey said even information marked classified email participants know know subject matter classified still obligated protect', 'update july 7 comey told congress three emails sent received clinton portion markings letter c body emails indicating presence classified information state department said believes least two emails marked error written separate story provides details', 'comey disabused clintons earlier claim efforts separate personal workrelated emails lawyers went every single email overly inclusive considered workrelated emails provided state department', 'clintons lawyers go every single email comey noted used header information search terms try find workrelated emails result comey said highly likely search missed workrelated emails', 'comey said fbi recovered several thousand workrelated emails provided state department said possible included emails deleted personal lawyers reviewed sorted emails production late 2014', 'interview msnbcs andrea mitchell september clinton said past secretaries state instructed state department october 2014 go emails separate personal workrelated ema ...

# %%
#create a word count for the normalized content
word_counts = Counter()

for paragraph in normalized_content:
    words = paragraph.split() 
    word_counts.update(words)

keywords_df = pd.DataFrame.from_dict(dict(word_counts.items()), orient='index', columns=['Count'])
keywords_df.sort_values(by='Count', ascending=False, inplace=True)  # Sort by count (descending)

# %%
# with open('keywords.csv', 'w', newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     writer.writerow(['Keyword'])  # Header row
#     for keyword in keyword_list:
#         writer.writerow([keyword])

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()


keyword_list = keywords_df.index.tolist()
# keyword_list = [word for word in keyword_list if word.lower() not in words_to_remove] 
related_tweets = []

import csv
iterations = 1000
passed = 0
count = 0
for chunk in elections_dataset:
    found = False
    for index, row in chunk.iterrows():
        passed += 1
        user = f"@{row['user_screen_name']}"
        type = row['tweet_type']
        message = row['text']
        if type != "retweet":
            for keyword in keyword_list:
                matched = False
                for word in message.split():
                    if keyword == word.lower():
                        print(keyword)
                        related_tweets.append(message)
                        count += 1
                        matched = True
                if matched == True:
                    break

        if count == iterations:
            found = True
            break

    if found == True:
        break

print(passed)
print(len(related_tweets))
# Out:
# went
# handling
# may
# clinton
# names
# debate
# case
# used
# may
# going
# take
# march
# us
# made
# hillary
# say
# public
# nothing
# first
# dumped
# say
# us
# clinton
# never
# never
# hillary
# could
# hillary
# time
# going
# one
# clinton
# us
# two
# clinton
# hand
# going
# least
# us
# hillary
# matter
# one
# people
# clinton
# say
# least
# private
# 10
# case
# take
# know
# hand
# released
# told
# time
# time
# instead
# going
# debate
# debate
# im
# hand
# could
# fact
# going
# go
# clinton
# could
# time
# hillary
# hillary
# even
# 4
# clinton
# people
# back
# us
# debate
# never
# people
# debate
# 10
# people
# take
# debate
# time
# top
# news
# even
# hillary
# hillary
# one
# look
# clinton
# may
# us
# never
# clinton
# hand
# hand
# last
# case
# anything
# r
# presidential
# debate
# us
# hillary
# hand
# business
# one
# top
# 2
# one
# news
# hillary
# benghazi
# presidential
# earlier
# emails
# campaign
# hand
# us
# time
# hillary
# still
# two
# well
# hillary
# clinton
# millions
# emails
# personal
# hillary
# way
# new
# time
# state
# people
# nation
# go
# people
# case
# 4
# going
# thought
# debate
# reasonable
# 4
# end
# campaign
# done
# personal
# 7
# well
# happened
# one
# time
# back
# way
# even
# two
# brought
# clinton
# closed
# first
# one
# made
# thats
# end
# going
# hillary
# going
# well
# 10
# 4
# 4
# 4
# way
# go
# team
# even
# may
# yes
# go
# debate
# still
# september
# clinton
# body
# way
# emails
# debate
# know
# hand
# presidential
# us
# clinton
# clinton
# hillary
# still
# know
# back
# know
# hillary
# never
# hillary
# also
# going
# people
# time
# go
# presidential
# year
# time
# going
# still
# us
# 4
# also
# clinton
# go
# people
# release
# could
# last
# even
# hillary
# take
# debate
# hand
# hand
# clinton
# millions
# found
# matter
# going
# back
# never
# debate
# march
# debate
# private
# never
# clinton
# go
# clintons
# go
# personal
# know
# go
# said
# event
# campaign
# us
# public
# us
# 2
# going
# 2
# one
# news
# presidential
# debate
# go
# private
# clinton
# time
# yes
# look
# never
# people
# later
# presidential
# people
# case
# clinton
# never
# never
# never
# instead
# clinton
# know
# way
# read
# two
# people
# matter
# matter
# try
# clintons
# never
# took
# already
# end
# look
# clinton
# take
# clinton
# anything
# anything
# 2
# clinton
# go
# us
# know
# presidential
# clinton
# brought
# take
# one
# general
# people
# case
# private
# hillary
# benghazi
# debate
# take
# town
# presidential
# may
# people
# going
# try
# time
# campaign
# 4
# even
# hillary
# clintons
# say
# go
# missed
# others
# hillary
# subject
# go
# said
# know
# clintons
# march
# go
# debate
# debate
# people
# told
# clinton
# time
# debate
# know
# clinton
# go
# say
# clinton
# common
# going
# clinton
# back
# know
# presidential
# later
# go
# hillary
# could
# 4
# going
# going
# time
# email
# presidential
# people
# everything
# past
# report
# debate
# debate
# two
# debate
# r
# nation
# even
# time
# clinton
# take
# hillary
# well
# presidential
# hillary
# way
# hillary
# clinton
# already
# way
# time
# look
# clinton
# know
# know
# hillary
# one
# clinton
# told
# emails
# year
# time
# going
# way
# time
# one
# know
# hillary
# still
# debate
# one
# back
# anything
# way
# went
# later
# 2
# may
# clinton
# people
# people
# never
# find
# debate
# possible
# people
# overly
# office
# 4
# 4
# even
# clinton
# words
# us
# go
# within
# already
# fact
# anyone
# clinton
# could
# clinton
# could
# time
# clinton
# clinton
# turned
# email
# clinton
# hand
# hillary
# release
# back
# well
# clinton
# may
# also
# find
# time
# go
# us
# campaign
# system
# one
# going
# ways
# emails
# clinton
# go
# debate
# secretary
# hillary
# office
# clinton
# done
# statements
# still
# clinton
# going
# past
# debate
# going
# may
# fact
# people
# know
# clinton
# going
# already
# clinton
# two
# nominee
# going
# debate
# 5
# news
# face
# one
# still
# presidential
# number
# im
# us
# presidential
# clinton
# case
# read
# year
# conduct
# people
# time
# r
# never
# face
# go
# sheet
# go
# go
# anything
# 4
# time
# time
# one
# people
# way
# debate
# clinton
# totally
# public
# 2
# us
# know
# went
# people
# debate
# r
# clintons
# hillary
# even
# hillary
# debate
# clinton
# im
# past
# know
# know
# look
# could
# matter
# private
# going
# use
# hillary
# read
# one
# 4
# several
# us
# us
# people
# clinton
# others
# past
# try
# state
# going
# 2
# debate
# every
# know
# every
# said
# never
# baron
# go
# one
# debate
# personal
# clinton
# years
# anything
# told
# clinton
# already
# way
# know
# may
# missed
# said
# us
# end
# clinton
# us
# know
# four
# 4
# people
# hillary
# 5
# press
# already
# anyone
# also
# going
# every
# know
# content
# private
# clinton
# debate
# go
# us
# still
# last
# clinton
# clinton
# people
# case
# every
# find
# hillary
# nothing
# totally
# clinton
# way
# presidential
# clinton
# us
# say
# said
# provide
# still
# private
# people
# people
# public
# single
# nominee
# hillary
# hillary
# words
# national
# hillary
# private
# private
# hillary
# among
# take
# made
# send
# way
# national
# case
# one
# clinton
# campaign
# 2
# us
# going
# top
# yes
# 5
# private
# 5
# two
# one
# clinton
# us
# email
# one
# told
# 2
# 2
# new
# say
# said
# could
# going
# go
# made
# know
# debate
# back
# way
# going
# presidential
# going
# campaign
# one
# people
# every
# every
# emails
# clinton
# clinton
# us
# clinton
# debate
# still
# 2015
# benghazi
# said
# two
# news
# clinton
# nothing
# clinton
# hillary
# private
# classified
# criminal
# two
# case
# since
# us
# told
# still
# also
# clinton
# 2
# clinton
# first
# new
# anyone
# one
# instead
# instead
# state
# time
# already
# clinton
# try
# every
# presidential
# hand
# said
# criminal
# take
# case
# clinton
# know
# clinton
# try
# fox
# years
# hillary
# one
# one
# us
# year
# march
# read
# efforts
# clinton
# fox
# know
# time
# way
# late
# clinton
# clinton
# said
# fox
# clinton
# going
# clinton
# time
# send
# go
# people
# people
# time
# concerned
# emails
# send
# way
# debate
# least
# words
# told
# find
# hillary
# clinton
# way
# people
# people
# debate
# last
# say
# last
# nothing
# case
# one
# hillary
# including
# us
# small
# hillary
# going
# time
# say
# debate
# national
# hillary
# never
# people
# hillary
# us
# people
# read
# time
# hillary
# clinton
# well
# end
# said
# 4
# nothing
# us
# people
# may
# one
# time
# fox
# hillary
# never
# clinton
# case
# 2
# others
# yes
# hillary
# gave
# every
# said
# done
# made
# us
# since
# time
# go
# last
# clinton
# go
# gave
# news
# go
# know
# clinton
# r
# take
# presidential
# try
# wrong
# say
# people
# still
# words
# know
# words
# 4
# first
# first
# first
# debate
# people
# case
# read
# read
# two
# debate
# clinton
# one
# cut
# end
# one
# march
# instead
# meet
# time
# go
# debate
# hillary
# personal
# town
# complete
# clintons
# public
# going
# going
# going
# people
# time
# produce
# clinton
# take
# business
# said
# presidential
# know
# 100
# clinton
# use
# know
# march
# done
# people
# hillary
# find
# clinton
# know
# debate
# clinton
# march
# hand
# brought
# one
# look
# us
# take
# one
# one
# millions
# every
# people
# clinton
# go
# never
# clinton
# take
# debate
# first
# news
# well
# people
# campaign
# clintons
# hillary
# 2
# even
# marked
# said
# well
# hillary
# hillary
# nothing
# r
# emails
# clinton
# said
# hand
# anyone
# yes
# case
# hillary
# anything
# use
# debate
# several
# know
# end
# least
# last
# us
# may
# instead
# last
# reasonable
# 4
# claim
# made
# say
# one
# never
# office
# r
# one
# clinton
# clinton
# send
# fox
# thought
# one
# news
# know
# personal
# 2
# done
# say
# anything
# hillary
# time
# well
# time
# time
# case
# 6086
# 1000

# %%
hashtags = []

for tweet in related_tweets:
    if "#" in tweet:
        words = tweet.split()  # Split the tweet into words
        for word in words:
            if word.startswith("#"): 
                hashtag = word.lower()  # Convert to lowercase (optional)
                hashtags.append(hashtag)

print(hashtags)
# Out:
# ['#iamvoting4jillbecause', '#gogreen', '#steinbaraka', '#debatenight', '#jillstein', '#washudebate2016', '#debate', '#msnbc', '#cnn', '#foxnews', '#debates2016', '#girlonthetrain', '#debate', '#debatenight', '#fightfor15', '#debates2016', '#sexistpig', '#debates2016', '#anonymous', '#justiceforjuanita', '#debates', '#debate', '#debates2016', '#debate', '#hillary', '#makeamericagreatagain', '#politician', '#debates', '#putin', '#wikileaks', '#emails', '#debate', '#trumpforever', '#debates', '#maga', '#trumptrain', '#politician', '#debates', '#debate', '#debatenight', '#debates', '#debatenight', '#maga', '#debates2016', '#podestraemails', '#wikileaksrelease', '#debates2016', '#debates', '#vpdebate', '#nbc4dc', '#debate', '#debatenight', '#debate', '#debates2016', '#debates2016', '#debate', '#debatenight', '#debate', '#debates2016', '#debates2016', '#wolfblitzer', '#debatenight', '#debate', '#debate', '#debate', '#debates', '#pussygrab', '#debates2016', '#debates2016', '#debat…', '#debates', '#debate', '#debates', '#debates2016', '#debates2016', '#bigleaguetruth', '#debate', '#iamvoting4jillbecause', '#gogreen', '#steinbaraka', '#debatenight', '#jillstein', '#washudebate2016', '#debates2016', '#debate2016', "#trump'll", '#debate', '#debates2016', '#debates', '#pence', '#debate', '#trump', '#debate2016', '#nomercy', '#debate', '#debatenight', '#debatenight', '#iamvoting4jillbecause', '#gogreen', '#steinbaraka', '#debatenight', '#jillstein', '#washudebate2016', '#debatetonight', '#debate', '#pussy', '#hrc2016', '#debatetonight', '#debate', '#pussy', '#hrc2016', '#debate', '#msnbc', '#cnn', '#foxnews', '#imwithher', '#nevertrump', '#debate', '#debate', '#debate2016', '#debates2016', '#maga', '#debates2016', '#wakeupamerica', '#maga', '#sundaynight', '#onceaponatime', '#debate', '#pussy', '#debate', '#business?', '#msm', '#soros', '#maga', '#debates2016', '#focus', '#debates', '#debatenight', '#debates2016', '#finishhimoff', '#debate', '#debatenight', '#debates', '#debatenight', '#maga', '#debates2016', '#debate', '#debates2016', '#nevertrump', '#hillary', '#abortion', '#lets', '#enoughlies', '#enoughofhillary', '#exposehillary', '#lockherup', '#rnc', '#debates2016', '#trump', '#debate', '#debates', '#debates2016', '#2016debate', '#debate', '#pleasetalkabouttheissues', '#pleaseimpressus', '#truth', '#debate', '#amiright', '#debate', '#lyingbitch', '#debates2016', '#debates2016', '#maga', '#washudebate2016', '#debates2016', '#askaboutabortion', '#debate', '#debate', '#debates', '#debate', '#neverhillary', '#debate', '#prayer', '#prayers', '#trump2016', '#maga', '#debate', '#debates', '#powerforpussy', '#debates', '#foxnews', '#specialreport', '#debate', '#cnn', '#sitroom', '#debate', '#trump', '#imwithher', '#debate', '#onesidedmedia', '#debatenight', '#trumppence', '#debate2016', '#vr!', '#debate', '#debates2016', '#trump', '#debatenight', '#debates2016', '#strawman', '#debate', '#debate', '#debate', '#election2016', '#hillaryforprison#debates2016', '#hillaryclintonhealth', '#debate', '#trump', '#clintons', '#nevertrump', '#debate', '#debateday', '#debates', '#donthecon', '#debate', '#democrats', '#debate', '#imwithher', '#hurricanematthew', '#flooding', '#lostpower', '#nc', '#fl', '#ga', '#sc', '#al', '#evacuated', '#debate', '#lovewhatmatters', '#debates2016', '#debate', '#debatenight', '#debate', '#debatenight', '#debatenight', '#debates2016', '#hillaryparadoxbook', '#debate', '#debate', '#debate', '#debate', '#debatenight', '#podestaemails', '#trump', '#debatenight', '#fightfor15', '#debate', '#imwithher', '#trump16', '#debatewitherin', '#debates2016', '#debate', '#debate', '#donaldtrump', '#whograbbedyou', '#debate', '#sexualassault', '#debates', '#trump', '#debates2016', '#debate', '#debate', '#moleg', '#debate', '#debate', '#trumppence2016', '#debatenight', '#debate', '#debates', '#clintonkaine2016', '#debate', '#debate', '#debate', '#presidentialcandidates', '#policebrutality', '#homelessness', '#poverty', '#racism', '#debate ...
